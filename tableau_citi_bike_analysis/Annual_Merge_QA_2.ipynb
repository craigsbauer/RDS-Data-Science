# %%
# Dependencies
import numpy as np
import pandas as pd
import requests
import os
import glob
import csv
import datetime as datetime

# %%
# import
df_2013 = pd.read_csv("citi_data_2013.csv")
df_2013.head(2)
# Out:
#    Unnamed: 0  tripduration            starttime             stoptime  \
# 0           0           634  2013-07-01 00:00:00  2013-07-01 00:10:34
# 1           1          1547  2013-07-01 00:00:02  2013-07-01 00:25:49
#
#    start station id start station name  start station latitude  \
# 0               164    E 47 St & 2 Ave               40.753231
# 1               388   W 26 St & 10 Ave               40.749718
#
#    start station longitude  end station id  end station name  \
# 0               -73.970325             504   1 Ave & E 15 St
# 1               -74.002950             459  W 20 St & 11 Ave
#
#    end station latitude  end station longitude  bikeid  usertype birth year  \
# 0             40.732219             -73.981656   16950  Customer         \N
# 1             40.746745             -74.007756   19816  Customer         \N
#
#    gender
# 0       0
# 1       0

# %%
df_2013.drop(['Unnamed: 0'], axis = 1, inplace = True, errors = 'ignore')

# %%
df_2013.tail(2)
# Out:
#          tripduration            starttime             stoptime  \
# 6071542          1166  2013-12-31 23:58:14  2014-01-01 00:17:40
# 6071543           677  2013-12-31 23:58:16  2014-01-01 00:09:33
#
#          start station id start station name  start station latitude  \
# 6071542               492    W 33 St & 7 Ave               40.750200
# 6071543               463    9 Ave & W 16 St               40.742065
#
#          start station longitude  end station id  end station name  \
# 6071542               -73.990931             253   W 13 St & 5 Ave
# 6071543               -74.004432             448  W 37 St & 10 Ave
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 6071542             40.735439             -73.994539   21022  Subscriber
# 6071543             40.756604             -73.997901   17559  Subscriber
#
#         birth year  gender
# 6071542       1955       1
# 6071543       1986       1

# %%
# import
df_2014 = pd.read_csv("citi_data_2014_FINAL.csv")
df_2014.head(2)
# Out:
# C:\Users\craig\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  tripduration            starttime             stoptime  \
# 0           0           471  2014-01-01 00:00:06  2014-01-01 00:07:57
# 1           1          1494  2014-01-01 00:00:38  2014-01-01 00:25:32
#
#    start station id        start station name  start station latitude  \
# 0              2009  Catherine St & Monroe St               40.711174
# 1               536           1 Ave & E 30 St               40.741444
#
#    start station longitude  end station id          end station name  \
# 0               -73.996826             263  Elizabeth St & Hester St
# 1               -73.975361             259   South St & Whitehall St
#
# ...

# %%
df_2014.drop(['Unnamed: 0'], axis = 1, inplace = True, errors = 'ignore')

# %%
df_2014.tail(2)
# Out:
#          tripduration            starttime             stoptime  \
# 8081214           332  2014-12-31 23:57:25  2015-01-01 00:02:57
# 8081215          2048  2014-12-31 23:58:16  2015-01-01 00:32:24
#
#          start station id     start station name  start station latitude  \
# 8081214               293  Lafayette St & E 8 St               40.730287
# 8081215               440        E 45 St & 3 Ave               40.752554
#
#          start station longitude  end station id      end station name  \
# 8081214               -73.990765             317     E 6 St & Avenue B
# 8081215               -73.972826             264  Maiden Ln & Pearl St
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 8081214             40.724537             -73.981854   15374  Subscriber
# 8081215             40.707065             -74.007319   20831  Subscriber
#
#         birth year  gender
# 8081214       1984       1
# 8081215       1984       1

# %%
# import
df_2015= pd.read_csv("citi_data_2015.csv")
df_2015.head(2)
# Out:
#    Unnamed: 0  tripduration            starttime             stoptime  \
# 0           0          1346  2015-01-01 00:01:00  2015-01-01 00:24:00
# 1           1           363  2015-01-01 00:02:00  2015-01-01 00:08:00
#
#    start station id start station name  start station latitude  \
# 0               455    1 Ave & E 44 St               40.750020
# 1               434    9 Ave & W 18 St               40.743174
#
#    start station longitude  end station id          end station name  \
# 0               -73.969053             265  Stanton St & Chrystie St
# 1               -74.003664             482           W 15 St & 7 Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.722293             -73.991475   18660  Subscriber
# 1             40.739355             -73.999318   16085  Subscriber
#
#    birth year  gender
# 0      1960.0       2
# 1      1963.0       1

# %%
df_2015.drop(['Unnamed: 0'], axis = 1, inplace = True, errors = 'ignore')

# %%
df_2015.tail(2)
# Out:
#          tripduration            starttime             stoptime  \
# 9937967           372  2015-12-31 21:20:38  2015-12-31 21:26:50
# 9937968           395  2015-12-31 21:49:19  2015-12-31 21:55:55
#
#          start station id          start station name  start station latitude  \
# 9937967              3242  Schermerhorn St & Court St               40.691029
# 9937968              3242  Schermerhorn St & Court St               40.691029
#
#          start station longitude  end station id    end station name  \
# 9937967               -73.991834             467     Dean St & 4 Ave
# 9937968               -73.991834             418  Front St & Gold St
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 9937967             40.683125             -73.978951   19782  Subscriber
# 9937968             40.702240             -73.982578   23411  Subscriber
#
#          birth year  gender
# 9937967      1987.0       1
# 9937968      1968.0       1

# %%
# import
df_2016= pd.read_csv("citi_data_2016_FINAL.csv")
df_2016.head(2)
# Out:
#    Unnamed: 0  bikeid  birth year  end station id  end station latitude  \
# 0         NaN   22285      1958.0            3002             40.711512
# 1         NaN   17827      1969.0             498             40.748549
#
#    end station longitude            end station name  gender  \
# 0             -74.015756  South End Ave & Liberty St       1
# 1             -73.988084          Broadway & W 32 St       1
#
#    start station id  start station latitude  start station longitude  \
# 0               268               40.719105               -73.999733
# 1               476               40.743943               -73.979661
#
#       start station name            starttime             stoptime  \
# 0  Howard St & Centre St  2016-01-01 00:00:41  2016-01-01 00:16:04
# 1        E 31 St & 3 Ave  2016-01-01 00:00:45  2016-01-01 00:07:04
#
#    tripduration    usertype
# 0           923  Subscriber
# 1           379  Subscriber

# %%
df_2016.drop(['Unnamed: 0'], axis = 1, inplace = True, errors = 'ignore')

# %%
df_2016.tail(2)
# Out:
#           bikeid  birth year  end station id  end station latitude  \
# 13845653   16866      1961.0            3169             40.787209
# 13845654   25793      1985.0             498             40.748549
#
#           end station longitude        end station name  gender  \
# 13845653             -73.981281  Riverside Dr & W 82 St       1
# 13845654             -73.988084      Broadway & W 32 St       1
#
#           start station id  start station latitude  start station longitude  \
# 13845653              3158               40.771639               -73.982614
# 13845654              3263               40.729236               -73.990868
#
#               start station name         starttime       stoptime  \
# 13845653      W 63 St & Broadway  12/31/2016 23:59  1/1/2017 0:15
# 13845654  Cooper Square & E 7 St  12/31/2016 23:59  1/1/2017 0:21
#
#           tripduration    usertype
# 13845653           951  Subscriber
# 13845654          1322  Subscriber

# %%
# import
df_2017 = pd.read_csv("citi_data_2017.csv")
df_2017.head(2)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           195  2017-04-01 00:00:58  2017-04-01 00:04:14               217
# 1           585  2017-04-01 00:01:54  2017-04-01 00:11:40               490
#
#   start station name  start station latitude  start station longitude  \
# 0      Old Fulton St               40.702772               -73.993836
# 1    8 Ave & W 33 St               40.751551               -73.993934
#
#    end station id    end station name  end station latitude  \
# 0             430    York St & Jay St             40.701485
# 1            3158  W 63 St & Broadway             40.771639
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -73.986569   25454  Subscriber      1966.0       1
# 1             -73.982614   25930  Subscriber      1995.0       1

# %%
df_2017.tail(2)
# Out:
#           tripduration            starttime             stoptime  \
# 12246447          1032  2017-03-31 23:59:49  2017-04-01 00:17:01
# 12246448           117  2017-03-29 11:57:54  2017-03-29 11:59:52
#
#           start station id    start station name  start station latitude  \
# 12246447               351  Front St & Maiden Ln               40.705310
# 12246448              3416       7 Ave & Park Pl               40.677615
#
#           start station longitude  end station id     end station name  \
# 12246447               -74.006126             302    Avenue D & E 3 St
# 12246448               -73.973243            3346  Berkeley Pl & 7 Ave
#
#           end station latitude  end station longitude  bikeid    usertype  \
# 12246447             40.720828             -73.977932   21097  Subscriber
# 12246448             40.675147             -73.975232   16750  Subscriber
#
#           birth year  gender
# 12246447      1978.0       1
# 12246448      1949.0       2

# %%
df_combined = pd.concat([df_2013, df_2014, df_2015, df_2017], ignore_index=True)
df_combined.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           634  2013-07-01 00:00:00  2013-07-01 00:10:34               164
# 1          1547  2013-07-01 00:00:02  2013-07-01 00:25:49               388
# 2           178  2013-07-01 00:01:04  2013-07-01 00:04:02               293
# 3          1580  2013-07-01 00:01:06  2013-07-01 00:27:26               531
# 4           757  2013-07-01 00:01:10  2013-07-01 00:13:47               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
# ...

# %%
df_combined.to_csv("citi_data_combined2.csv", index = False, encoding='utf-8')

# %%
df_combined.shape[0]
len(df_combined)
# Out:
# 36337178
