# %%
# Dependencies
import numpy as np
import pandas as pd
import requests
import os
import glob
import csv
import datetime as datetime

# %%
# import
df_combined = pd.read_csv("citi_data_combined.csv")
df_combined.tail(2)
# Out:
# C:\Users\craig\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           tripduration            starttime             stoptime  \
# 36337176          1032  2017-03-31 23:59:49  2017-04-01 00:17:01
# 36337177           117  2017-03-29 11:57:54  2017-03-29 11:59:52
#
#           start station id    start station name  start station latitude  \
# 36337176               351  Front St & Maiden Ln               40.705310
# 36337177              3416       7 Ave & Park Pl               40.677615
#
#           start station longitude  end station id     end station name  \
# 36337176               -74.006126             302    Avenue D & E 3 St
# 36337177               -73.973243            3346  Berkeley Pl & 7 Ave
#
# ...

# %%
#convert dtpye
pd.to_datetime(df_combined['starttime'])
#pd.to_datetime(df_combined['stoptime'])
# Out:
# 0          2013-07-01 00:00:00
# 1          2013-07-01 00:00:02
# 2          2013-07-01 00:01:04
# 3          2013-07-01 00:01:06
# 4          2013-07-01 00:01:10
# 5          2013-07-01 00:01:23
# 6          2013-07-01 00:01:59
# 7          2013-07-01 00:02:16
# 8          2013-07-01 00:02:16
# 9          2013-07-01 00:02:23
# 10         2013-07-01 00:02:23
# 11         2013-07-01 00:02:24
# 12         2013-07-01 00:02:24
# 13         2013-07-01 00:02:33
# 14         2013-07-01 00:02:44
# 15         2013-07-01 00:03:10
# 16         2013-07-01 00:03:14
# 17         2013-07-01 00:03:30
# 18         2013-07-01 00:03:58
# 19         2013-07-01 00:04:10
# 20         2013-07-01 00:05:09
# 21         2013-07-01 00:05:26
# 22         2013-07-01 00:05:31
# 23         2013-07-01 00:05:35
# 24         2013-07-01 00:05:37
# 25         2013-07-01 00:05:41
# 26         2013-07-01 00:05:47
# 27         2013-07-01 00:05:49
# 28         2013-07-01 00:05:51
# 29         2013-07-01 00:06:27
# ...

# %%
df_combined.tail(2)
# Out:
#           tripduration            starttime             stoptime  \
# 36337176          1032  2017-03-31 23:59:49  2017-04-01 00:17:01
# 36337177           117  2017-03-29 11:57:54  2017-03-29 11:59:52
#
#           start station id    start station name  start station latitude  \
# 36337176               351  Front St & Maiden Ln               40.705310
# 36337177              3416       7 Ave & Park Pl               40.677615
#
#           start station longitude  end station id     end station name  \
# 36337176               -74.006126             302    Avenue D & E 3 St
# 36337177               -73.973243            3346  Berkeley Pl & 7 Ave
#
#           end station latitude  end station longitude  bikeid    usertype  \
# 36337176             40.720828             -73.977932   21097  Subscriber
# 36337177             40.675147             -73.975232   16750  Subscriber
#
#          birth year  gender
# 36337176       1978       1
# 36337177       1949       2

# %%
#df_combined['usertype'].dtype
df_combined.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                  object
# gender                       int64
# dtype: object

# %%
test = df_combined.sort_values('starttime', ascending=False)

# %%
# import
dfs_2016 = pd.read_csv("citi_data_2016_FINAL3.csv")
dfs_2016.head(2)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           923  2016-01-01 00:00:41  2016-01-01 00:16:04               268
# 1           379  2016-01-01 00:00:45  2016-01-01 00:07:04               476
#
#       start station name  start station latitude  start station longitude  \
# 0  Howard St & Centre St               40.719105               -73.999733
# 1        E 31 St & 3 Ave               40.743943               -73.979661
#
#    end station id            end station name  end station latitude  \
# 0            3002  South End Ave & Liberty St             40.711512
# 1             498          Broadway & W 32 St             40.748549
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -74.015756   22285  Subscriber      1958.0       1
# 1             -73.988084   17827  Subscriber      1969.0       1

# %%
df_combinedFINAL = pd.concat([df_combined, dfs_2016], ignore_index=True)
df_combinedFINAL.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           634  2013-07-01 00:00:00  2013-07-01 00:10:34               164
# 1          1547  2013-07-01 00:00:02  2013-07-01 00:25:49               388
# 2           178  2013-07-01 00:01:04  2013-07-01 00:04:02               293
# 3          1580  2013-07-01 00:01:06  2013-07-01 00:27:26               531
# 4           757  2013-07-01 00:01:10  2013-07-01 00:13:47               382
#
#         start station name  start station latitude  start station longitude  \
# 0          E 47 St & 2 Ave               40.753231               -73.970325
# 1         W 26 St & 10 Ave               40.749718               -74.002950
# 2    Lafayette St & E 8 St               40.730287               -73.990765
# 3   Forsyth St & Broome St               40.718939               -73.992663
# 4  University Pl & E 14 St               40.734927               -73.992005
#
# ...

# %%
df_combinedFINAL.to_csv("citi_data_combinedFINAL.csv", index = False, encoding='utf-8')
