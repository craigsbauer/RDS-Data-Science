# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
import time

# OpenWeather API Key
api_key = "d9cc2b43f4569d1bd791efaeac304dc7"
units = "metric"

# %%
# Import cities file as DataFrame
cities_pd = pd.read_csv("worldcities.csv")
cities_pd.head()
# Out:
#             city   city_ascii        lat        lng       pop      country  \
# 0  Qal eh-ye Now    Qal eh-ye  34.983000  63.133300    2997.0  Afghanistan
# 1    Chaghcharan  Chaghcharan  34.516701  65.250001   15000.0  Afghanistan
# 2    Lashkar Gah  Lashkar Gah  31.582998  64.360000  201546.0  Afghanistan
# 3         Zaranj       Zaranj  31.112001  61.886998   49851.0  Afghanistan
# 4     Tarin Kowt   Tarin Kowt  32.633298  65.866699   10000.0  Afghanistan
#
#   iso2 iso3 province
# 0   AF  AFG  Badghis
# 1   AF  AFG     Ghor
# 2   AF  AFG  Hilmand
# 3   AF  AFG   Nimroz
# 4   AF  AFG  Uruzgan

# %%
# Add columns for Temperature, Humidity, Cloudiness, Wind Speed
# Note that we used "" to specify initial entry.
cities_pd["Temperature_C"] = ""
cities_pd["Temperature_F"] = ""
cities_pd["Humidity"] = ""
cities_pd["Cloudiness"] = ""
cities_pd["Wind_Speed"] = ""

cities_pd.head()
# Out:
#             city   city_ascii        lat        lng       pop      country  \
# 0  Qal eh-ye Now    Qal eh-ye  34.983000  63.133300    2997.0  Afghanistan
# 1    Chaghcharan  Chaghcharan  34.516701  65.250001   15000.0  Afghanistan
# 2    Lashkar Gah  Lashkar Gah  31.582998  64.360000  201546.0  Afghanistan
# 3         Zaranj       Zaranj  31.112001  61.886998   49851.0  Afghanistan
# 4     Tarin Kowt   Tarin Kowt  32.633298  65.866699   10000.0  Afghanistan
#
#   iso2 iso3 province Temperature_C Temperature_F Humidity Cloudiness  \
# 0   AF  AFG  Badghis
# 1   AF  AFG     Ghor
# 2   AF  AFG  Hilmand
# 3   AF  AFG   Nimroz
# 4   AF  AFG  Uruzgan
#
#   Wind_Speed
# 0
# 1
# 2
# 3
# 4

# %%
# Random selection of 500 cities with a population >1000
# Using 500 cities to stay within OpenWeatherMap limit
selected_cities = cities_pd.sample(n=10)
selected_cities = selected_cities[selected_cities["pop"].astype(int) > 1000]

# View selected_cities
selected_cities.head()
selected_cities
# Out:
#             city  city_ascii        lat         lng        pop       country  \
# 3611      Kitale      Kitale   1.030466   34.989947   112809.0         Kenya
# 5538     Tzaneen     Tzaneen -23.819542   30.169982    42099.5  South Africa
# 6139    Funafuti    Funafuti  -8.516652  179.216647     4749.0        Tuvalu
# 3210   Palembang   Palembang  -2.980039  104.750030  1595250.0     Indonesia
# 4595      Motupe      Motupe  -6.150026  -79.710003     9048.0          Peru
# 5887     Mpwapwa     Mpwapwa  -6.349601   36.479985    10093.5      Tanzania
# 2248     Heredia     Heredia   9.991998  -84.120003    21947.0    Costa Rica
# 502   Queenstown  Queenstown -42.082924  145.550020     1658.0     Australia
# 5298    Belgorod    Belgorod  50.629996   36.599926   328004.5        Russia
#
#      iso2 iso3          province Temperature_C Temperature_F Humidity  \
# 3611   KE  KEN       Rift Valley
# 5538   ZA  ZAF           Limpopo
# 6139   TV  TUV               NaN
# 3210   ID  IDN  Sumatera Selatan
# 4595   PE  PER        Lambayeque
# 5887   TZ  TZA            Dodoma
# 2248   CR  CRI           Heredia
# 502    AU  AUS          Tasmania
# 5298   RU  RUS          Belgorod
#
#      Cloudiness Wind_Speed
# 3611
# 5538
# 6139
# 3210
# 4595
# 5887
# 2248
# 502
# 5298

# %%
# Loop through the cities_pd and run a temp search for each city
for index, row in selected_cities.iterrows():
    target_url = "http://api.openweathermap.org/data/2.5/weather?" 
  
    # Wait 60 seconds before doing anything else
#     time.sleep(1)
    
    # Build query URL
    query_url = target_url + "appid=" + api_key + "&q=" + (row["city"])
#     print(query_url)
    cities_data = requests.get(query_url).json()
    try: 
        selected_cities.set_value(index, "Temperature_C", cities_data["main"]["temp"])
        selected_cities.set_value(index, "Humidity", cities_data["main"]["humidity"])
        selected_cities.set_value(index, "Cloudiness", cities_data["clouds"]["all"])
        selected_cities.set_value(index, "Wind_Speed", cities_data["wind"]["speed"])
#         print(target_url)    
                                                           
    except:
#         #
#         print("Error with data. Skipping")
        continue
                
# View selected_cities for added data
selected_cities
# Out:
#             city  city_ascii        lat         lng        pop       country  \
# 3611      Kitale      Kitale   1.030466   34.989947   112809.0         Kenya
# 5538     Tzaneen     Tzaneen -23.819542   30.169982    42099.5  South Africa
# 6139    Funafuti    Funafuti  -8.516652  179.216647     4749.0        Tuvalu
# 3210   Palembang   Palembang  -2.980039  104.750030  1595250.0     Indonesia
# 4595      Motupe      Motupe  -6.150026  -79.710003     9048.0          Peru
# 5887     Mpwapwa     Mpwapwa  -6.349601   36.479985    10093.5      Tanzania
# 2248     Heredia     Heredia   9.991998  -84.120003    21947.0    Costa Rica
# 502   Queenstown  Queenstown -42.082924  145.550020     1658.0     Australia
# 5298    Belgorod    Belgorod  50.629996   36.599926   328004.5        Russia
#
#      iso2 iso3          province Temperature_C Temperature_F Humidity  \
# 3611   KE  KEN       Rift Valley        291.99                     97
# 5538   ZA  ZAF           Limpopo        296.99                     55
# 6139   TV  TUV               NaN        300.15                     88
# 3210   ID  IDN  Sumatera Selatan        299.15                     78
# 4595   PE  PER        Lambayeque        290.15                     88
# 5887   TZ  TZA            Dodoma        298.84                     52
# 2248   CR  CRI           Heredia        291.66                     93
# 502    AU  AUS          Tasmania        295.24                     41
# 5298   RU  RUS          Belgorod        297.15                     33
#
#      Cloudiness Wind_Speed
# 3611         76       1.33
# 5538          0       1.71
# 6139         75          1
# 3210         40        1.5
# 4595         90        2.6
# 5887          8       4.43
# 2248          0          1
# 502          48       0.11
# 5298          0          6

# %%
# Convert Celcius to Fahrenheit
        cel=int("Temperature_C")
        far=(9/5*(cel))+32
        selected_cities.set_value(index, "Temperature_F", far)
selected_cities.head()
# Out:
#   File "<ipython-input-6-a72d1ac9f955>", line 2
#     cel=int("Temperature_C")
#     ^
# IndentationError: unexpected indent

# %%
# Build a scatter plot for Temperature and Latitude
plt.scatter(selected_cities["Temperature_F"], 
            selected_cities["Latitude"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")

# Incorporate the other graph properties
plt.title("Temperature vs. Latitude by City")
plt.ylabel("Temperature_F")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-2.5, 150])
plt.ylim([-2.5, 110000])

# Save the figure
plt.savefig("output_analysis/Temperature_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for Humidity and Latitude
plt.scatter(selected_cities["Humidity"], 
            selected_cities["Latitude"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")

# Incorporate the other graph properties
plt.title("Humidity vs. Latitude by City")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-2.5, 150])
plt.ylim([-2.5, 110000])

# Save the figure
plt.savefig("output_analysis/Humidity_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for Cloudiness and Latitude
plt.scatter(selected_cities["Cloudiness"], 
            selected_cities["Latitude"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")

# Incorporate the other graph properties
plt.title("Cloudiness vs. Latitude by City")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-2.5, 150])
plt.ylim([-2.5, 110000])

# Save the figure
plt.savefig("output_analysis/Cloudiness_Latitude.png")

# Show plot
plt.show()

# %%
# Build a scatter plot for Wind_Speed and Latitude
plt.scatter(selected_cities["Wind_Speed"], 
            selected_cities["Latitude"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="City")

# Incorporate the other graph properties
plt.title("Wind_Speed vs. Latitude by City")
plt.ylabel("Wind_Speed")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-2.5, 150])
plt.ylim([-2.5, 110000])

# Save the figure
plt.savefig("output_analysis/Wind_Speed_Latitude.png")

# Show plot
plt.show()
