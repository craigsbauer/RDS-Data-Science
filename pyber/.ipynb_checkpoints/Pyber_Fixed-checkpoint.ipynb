# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load in file
city_data = "city_data4.csv"
ride_data = "ride_data_original.csv"

# %%
# Create DataFrame from city CSV
city_df = pd.read_csv(city_data, low_memory=False)
city_df.head()
# Out:
#              city  driver_count   type
# 0      Kelseyland            63  Urban
# 1      Nguyenbury             8  Urban
# 2    East Douglas            12  Urban
# 3   West Dawnfurt            34  Urban
# 4  Rodriguezburgh            52  Urban

# %%
# Create DataFrame from ride CSV
ride_df = pd.read_csv(ride_data, low_memory=False)
ride_df.head()
# Out:
#           city             date   fare       ride_id
# 0     Sarabury  1/16/2016 13:49  38.35  5.403689e+12
# 1    South Roy   1/2/2016 18:42  17.49  4.036272e+12
# 2  Wiseborough  1/21/2016 17:35  44.18  3.645042e+12
# 3  Spencertown  7/31/2016 14:53   6.87  2.242597e+12
# 4   Nguyenbury    7/9/2016 4:42   6.28  1.543058e+12

# %%
# Merge the two created data frames by city
merged_df = pd.merge(ride_df, city_df, on = "city", how="left")
merged_df.head()
# Out:
#           city             date   fare       ride_id  driver_count   type
# 0     Sarabury  1/16/2016 13:49  38.35  5.403689e+12          46.0  Urban
# 1    South Roy   1/2/2016 18:42  17.49  4.036272e+12          35.0  Urban
# 2  Wiseborough  1/21/2016 17:35  44.18  3.645042e+12          55.0  Urban
# 3  Spencertown  7/31/2016 14:53   6.87  2.242597e+12          68.0  Urban
# 4   Nguyenbury    7/9/2016 4:42   6.28  1.543058e+12           8.0  Urban

# %%
# Calc Average Fare ($) Per City
average_fare_city = merged_df.groupby(["type"]).mean()["fare"]
average_fare_city
# Out:
# type
# Rural       34.040720
# Suburban    30.952344
# Urban       24.663594
# Name: fare, dtype: float64

# %%
# Calc Total Number of Rides Per City
total_rides_city = merged_df.groupby(["type"]).nunique()["fare"]
total_rides_city
# Out:
# type
# Rural        124
# Suburban     575
# Urban       1344
# Name: fare, dtype: int64

# %%
# Calc Total Number of Drivers Per City Type
total_drivers_city = merged_df.groupby(["type"])["driver_count"].nunique()
total_drivers_city
# Out:
# type
# Rural        8
# Suburban    25
# Urban       42
# Name: driver_count, dtype: int64

# %%
# Calc Total Fares ($) Per City
total_fare = merged_df.groupby(["type"]).sum()["fare"]
total_fare = total_fare.map("${:,.2f}".format)
total_fare
# Out:
# type
# Rural        $4,255.09
# Suburban    $20,335.69
# Urban       $40,078.34
# Name: fare, dtype: object

# %%
# Create a DataFrame to hold results
per_type_summary = pd.DataFrame({"Average Fare per City": average_fare_city,
                                   "Total Number of Rides Per City": total_rides_city,
                                   "Total Number of Drivers Per City": total_drivers_city})

per_type_summary["Average Fare per City"] = per_type_summary["Average Fare per City"].map("${:,.2f}".format)

# Display the data frame
per_type_summary
# Out:
#          Average Fare per City  Total Number of Drivers Per City  \
# type
# Rural                   $34.04                                 8
# Suburban                $30.95                                25
# Urban                   $24.66                                42
#
#           Total Number of Rides Per City
# type
# Rural                                124
# Suburban                             575
# Urban                               1344

# %%
# % of Total Fares by City Type using conditionals
rural_fare = merged_df[(merged_df["type"] == "Rural")]
rural_fare
# Out:
#                       city              date   fare       ride_id  \
# 2392           Jacksonfort  10/20/2016 16:42  37.75  4.356782e+12
# 2393          South Joseph   10/15/2016 3:53  32.50  2.758038e+12
# 2394           Matthewside    5/18/2016 2:00  48.67  2.049161e+12
# 2395           Matthewside    8/8/2016 14:02  24.97  2.872495e+12
# 2396          South Joseph   10/28/2016 9:52  25.34  6.706102e+12
# 2397  South Elizabethmouth    7/19/2016 9:35  31.09  2.959750e+12
# 2398         North Whitney  11/11/2016 16:24  22.99  3.454326e+12
# 2399          New Johnbury    8/29/2016 2:36  18.83  7.368222e+12
# 2400           East Leslie    6/22/2016 7:45  34.54  6.849501e+11
# 2401          Kennethburgh    6/7/2016 11:43  56.02  3.117332e+11
# 2402        West Kevintown    2/10/2016 0:50  34.69  9.595491e+12
# 2403         East Troybury    3/14/2016 1:55  38.80  9.205811e+12
# 2404         North Whitney    1/26/2016 1:06  34.92  4.165974e+12
# 2405          South Joseph    9/28/2016 7:30  12.55  4.336213e+12
# 2406  South Elizabethmouth   4/21/2016 10:20  16.50  5.702608e+12
#
#       driver_count   type
# 2282           8.0  Rural
# 2283           3.0  Rural
# 2284           6.0  Rural
# 2285           3.0  Rural
# 2286           3.0  Rural
# 2287           6.0  Rural
# 2288           6.0  Rural
# 2289           5.0  Rural
# 2290           3.0  Rural
# 2291           3.0  Rural
# 2292          10.0  Rural
# 2293           6.0  Rural
# 2294           9.0  Rural
# 2295           8.0  Rural
# 2296           6.0  Rural
# 2297           6.0  Rural
# 2298          10.0  Rural
# 2299           9.0  Rural
# 2300           7.0  Rural
# 2301           3.0  Rural
# 2302          10.0  Rural
# 2303           3.0  Rural
# 2304           9.0  Rural
# 2305          10.0  Rural
# 2306           6.0  Rural
# 2307           3.0  Rural
# 2308           3.0  Rural
# 2309           9.0  Rural
# 2310           5.0  Rural
# 2311           9.0  Rural
# ...            ...    ...
# 2377           5.0  Rural
# 2378           4.0  Rural
# 2379           3.0  Rural
# 2380           3.0  Rural
# 2381          10.0  Rural
# 2382           3.0  Rural
# 2383           6.0  Rural
# 2384           3.0  Rural
# 2385           6.0  Rural
# 2386           6.0  Rural
# 2387           3.0  Rural
# 2388           8.0  Rural
# 2389           9.0  Rural
# 2390           3.0  Rural
# 2391           3.0  Rural
# 2392           6.0  Rural
# 2393           3.0  Rural
# 2394           4.0  Rural
# 2395           4.0  Rural
# 2396           3.0  Rural
# 2397           3.0  Rural
# 2398          10.0  Rural
# 2399           6.0  Rural
# 2400           9.0  Rural
# 2401           3.0  Rural
# 2402           5.0  Rural
# 2403           3.0  Rural
# 2404          10.0  Rural
# 2405           3.0  Rural
# 2406           3.0  Rural
#
# [125 rows x 6 columns]

# %%
# % of Total Rides by City Type

# %%
# % of Total Drivers by City Type
Rural_percent = (total_rides_city/) * 100

# %%
# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [185, 172, 100, 110]

# The colors of each section of the pie chart
colors = ["gold", "light sky blue", "lightcoral"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0, 0)
